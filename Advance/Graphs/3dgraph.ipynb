# %%
import numpy as np
from numpy import linspace
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D

# %%
iris= pd.read_csv("D:\Progrmming\Python\Advance\Graphs\Iris.csv")
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
x = iris['PetalWidthCm']
y = iris['PetalLengthCm']
z = iris['SepalLengthCm']
#plotting
ax.scatter(x,y,z,c='green')
ax.set_title('3d scatter plot')
ax.set_xlabel('PetalWidthCm')
ax.set_ylabel('PetalLengthCm')
ax.set_zlabel('SepalLengthCm')
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.view_init(elev=10, azim=50,roll=13)
x = iris['PetalWidthCm']
y = iris['PetalLengthCm']
z = iris['SepalLengthCm']
#plotting
ax.scatter(x,y,z,c='red')
ax.set_title('3d scatter plot')
ax.set_xlabel('PetalWidthCm')
ax.set_ylabel('PetalLengthCm')
ax.set_zlabel('SepalLengthCm')
plt.show()

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np


fig = plt.figure()
ax = plt.axes(projection='3d')
x = iris['PetalWidthCm']
y = iris['PetalLengthCm']
z = iris['SepalLengthCm']
#plotting
ax.scatter(x,y,z,c='red')
ax.set_title('3d scatter plot')
ax.set_xlabel('PetalWidthCm')
ax.set_ylabel('PetalLengthCm')
ax.set_zlabel('SepalLengthCm')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np
from numpy import linspace
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D

data= pd.read_csv("D:\Progrmming\Python\Advance\Graphs\Iris.csv")


fig = plt.figure()
ax = plt.axes(projection='3d')
x = data['PetalWidthCm'].sort_values()
y = data['PetalLengthCm'].sort_values()

z = data['SepalLengthCm'].sort_values()
#plotting
ax.plot3D(x,y,z,c='black')
ax.set_title('3d scatter plot')
ax.set_xlabel('PetalWidthCm')
ax.set_ylabel('PetalLengthCm')
ax.set_zlabel('SepalLengthCm')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#mpl.rcParams['font.size']=10
df= pd.read_csv("D:\Progrmming\Python\Advance\Graphs\Iris.csv")

setosa=df[df['Species']=='Iris-setosa']
versicolor=df[df['Species']=='Iris-versicolor']
virginica=df[df['Species']=='Iris-virginica']

fig = plt.figure
ax=fig.add_subplot(111,projection='3d')
ax.bar(setosa['Id'],setosa['PetalWidthCm'],zs=1,zdir='x',color="red",alpha=0.8)
ax.bar(versicolor['Id'],versicolor['PetalWidthCm'],zs=2,zdir='x',color="red",alpha=0.8)
ax.bar(virginica['Id'],virginica['PetalWidthCm'],zs=3,zdir='x',color="red",alpha=0.8)
ax.set_xlabel('Species')
ax.set_ylabel('Id')
ax.set_zlabel('PetalWidthCm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 9
#       6 virginica=df[df['Species']=='Iris-virginica']
#       8 fig = plt.figure
# ----> 9 ax=fig.add_subplot(111,projection='3d')
#      10 ax.bar(setosa['Id'],setosa['PetalWidthCm'],zs=1,zdir='x',color="red",alpha=0.8)
#      11 ax.bar(versicolor['Id'],versicolor['PetalWidthCm'],zs=2,zdir='x',color="red",alpha=0.8)
#
# AttributeError: 'function' object has no attribute 'add_subplot'
