# %%
import numpy as np
from numpy import linspace
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D
from scipy import signal
from mpl_toolkits.basemap import Basemap

plt.figure(figsize=(5,5))
m=Basemap(projection='ortho',resolution=None,lat_0=20.5937,lon_0=78.9629)
m.bluemarble(scale=0.5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.figure(figsize=(5,5))
m=Basemap(projection='merc',resolution='c',lat_0=20.5937,lon_0=78.9629)
m.bluemarble(scale=0.5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.figure(figsize=(5,5))
m=Basemap(projection='robin',resolution='c',lat_0=20.5937,lon_0=78.9629)
m.bluemarble(scale=0.5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.figure(figsize=(5,5))
m=Basemap(projection='lcc',resolution='c',lat_0=20.5937,lon_0=78.9629)
m.bluemarble(scale=0.5)

# %%
#ortho - circle, cyl - flat, merc - , robin - flat but oval, merc - rectangle long, lcc - wodth and height
#using LCC

plt.figure(figsize=(5,5))
m= Basemap(projection='lcc',resolution=None,lat_0=20.4735,lon_0=40.9754, width=8E6,height=8E6)
m.etopo(scale=0.5,alpha = 0.5)
x,y=m(55,22)
plt.plot(x,y,'ok',markersize=3)
plt.text(x,y,'Muscat',fontsize=12)


m.bluemarble(scale=1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
fig=plt.figure(figsize=(12,12))
m=Basemap()
m.drawcoastlines(linewidth=1.0,linestyle='dashed',color='red')
m.drawcountries(linewidth=1.0,linestyle='solid',color='k')
plt.title("Coastlines",fontsize=20)
x,y=m(75,22)
plt.plot(x,y,'ok',markersize=3)
plt.text(x,y,'India',fontsize=12)

plt.show()

# %%
fig=plt.figure(figsize=(12,12))
m=Basemap()
m.drawcoastlines(linewidth=1.0,linestyle='dashed',color='red')
m.drawcountries(linewidth=1.0,linestyle='solid',color='k')
m.drawrivers(linewidth=0.5,linestyle='solid',color='#0000ff')
plt.title("Major Rivers",fontsize=20)
x,y=m(75,22)
plt.plot(x,y,'ok',markersize=3)
plt.text(x,y,'India',fontsize=12)

plt.show()

# %%
fig=plt.figure(figsize=(12,12))
m=Basemap()
m.drawcoastlines(linewidth=1.0,linestyle='dashed',color='black')
#m.drawcountries(linewidth=1.0,linestyle='solid',color='k')
#m.drawrivers(linewidth=0.5,linestyle='solid',color='#0000ff')
m.fillcontinents(color='coral',lake_color='aqua')

# 20 degree graticule.
#m.drawparallels(np.arange(-80,81,20))
m.drawmeridians(range(0,360,20),color='k',linewidth=1.0,dashes=[4,4],labels=[0,0,1,1])
m.drawparallels(range(-90,100,20),color='k',linewidth=1.0,dashes=[4,4],labels=[1,0,0,0])
plt.title("meridians and parallels",fontsize=10,pad=30)

plt.show()

# %%
fig=plt.figure(figsize=(12,12))
m=Basemap()
m.drawcoastlines(linewidth=1.0,linestyle='dashed',color='black')
#m.drawcountries(linewidth=1.0,linestyle='solid',color='k')
#m.drawrivers(linewidth=0.5,linestyle='solid',color='#0000ff')
m.fillcontinents(color='coral',lake_color='aqua')

# 20 degree graticule.
#m.drawparallels(np.arange(-80,81,20))
m.drawmeridians(range(0,360,20),color='k',linewidth=1.0,dashes=[4,4],labels=[0,0,1,1])
m.drawparallels(range(-90,100,20),color='k',linewidth=1.0,dashes=[4,4],labels=[1,0,0,0])
plt.title("meridians and parallels",fontsize=10,pad=30)
m.drawmapboundary(fill_color='aqua') 

plt.show()

# %%
fig=plt.figure(figsize=(12,12))
m=Basemap()
m.drawcoastlines(linewidth=1.0,linestyle='dashed',color='black')
#m.drawcountries(linewidth=1.0,linestyle='solid',color='k')
#m.drawrivers(linewidth=0.5,linestyle='solid',color='#0000ff')
m.fillcontinents(color='coral',lake_color='aqua')

# 20 degree graticule.
#m.drawparallels(np.arange(-80,81,20))
m.drawmeridians(range(0,360,20),color='k',linewidth=1.0,dashes=[4,4],labels=[0,0,1,1])

# Draw parallels
m.drawparallels(range(-90, 100, 20), color='k', linewidth=1.0, dashes=[4, 4], labels=[1, 0, 0, 0])

# Draw major gridlines
m.drawparallels(range(-90, 100, 10), color='k', linewidth=0.5, dashes=[2, 2], labels=[0, 0, 0, 0])

# Draw minor gridlines
m.drawmeridians(range(0, 360, 10), color='k', linewidth=0.5, dashes=[2, 2], labels=[0, 0, 0, 0])


plt.title("meridians and parallels",fontsize=10,pad=30)
m.drawmapboundary(fill_color='aqua') 

plt.show()

# %%
fig = plt.figure(figsize = (10,6))
m= Basemap(projection='ortho',lat_0=45,lon_0=-100,resolution='l')
m.drawcoastlines(linewidth=1.0,linestyle='dashed',color='red')
m.drawcountries(linewidth=1.0,linestyle='solid',color='k')
m.fillcontinents(color='coral',lake_color='aqua')
# m.drawmeridians(range(0,360,20),color='k',linewidth=1.0,dashes=[4,4],labels=[0,0,1,1])
m.drawparallels(range(-90,100,20),color='k',linewidth=1.0,dashes=[4,4],labels=[1,0,0,0])
plt.title("Contour lines over filled continent background",fontsize=20,pad=30)
m.drawmapboundary(fill_color='aqua')
# draw lat/lon grid lines every 30 degrees.
m.drawmeridians(np.arange(0,360,30))
m.drawparallels(np.arange(-90,90,30))
# make up some data on a regular lat/lon grid.
nlats = 73; nlons = 145; delta = 2.*np.pi/(nlons-1)
lats = (0.5*np.pi-delta*np.indices((nlats,nlons))[0,:,:])
lons = (delta*np.indices((nlats,nlons))[1,:,:])
wave = 0.75*(np.sin(2.*lats)**8*np.cos(4.*lons))
mean = 0.5*np.cos(2.*lats)*((np.sin(2.*lats))**2 + 2.)
# compute native map projection coordinates of lat/lon grid.
x, y = m(lons*180./np.pi, lats*180./np.pi)
# contour data over the map.
cs = m.contour(x,y,wave+mean,15,linewidths=1.5)
plt.show()

# %%
from PIL import Image
filename = "min.jpg"
with Image.open(filename) as img:
    img.load()

# %%
print(type(img))
print(isinstance(img,Image.Image))
print(img.show())
print(img.format)
print(img.size)
print(img.mode)
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# True
# None
# JPEG
# (1920, 1064)
# RGB

# %%
cropped_img = img.crop((300,150,700,1000))# left 300 ,top 150 , right 700, bottom 1000----considering top left and right bottom ---
print(cropped_img.size)
print(cropped_img.show())
# Out:
# (400, 850)
# None

# %%
low_res_img = cropped_img.resize(
    (cropped_img.width//3, cropped_img.height//2)
)
low_res_img.show()

# %%
low_res_img = cropped_img.reduce(4)
low_res_img.show()

# %%
cropped_img.save("cropped_img.jpg")
low_res_img.save("low_res_image.png")

# %%
img.transpose(Image.FLIP_TOP_BOTTOM).show()

# %%
img.transpose(Image.FLIP_LEFT_RIGHT).show()

# %%
img.transpose(Image.ROTATE_90).show()

# %%
img.transpose(Image.ROTATE_270).show()

# %%
img.transpose(Image.ROTATE_180).show()

# %%
img.transpose(Image.TRANSPOSE).show()

# %%
img.rotate(45).show()

# %%
img.rotate(45,expand=True).show()

# %%
img.transpose(Image.TRANSVERSE).show()
